# %%
from functools import reduce
import numpy as np
import matplotlib.pyplot as plt

def qinjiushao(coefficient, x0):
    '''
    factors表示系数向量,按照x次幂从大到小依次降低
    如题目中,factors取[7,3,-5,11]
    x0表示估值点
    '''
    value = reduce(lambda a,b:a*x0+b,factors )
    return value 



factors=[1,-18,144,-672,2016,-4032,5376,-4608,2304,-512]

x = np.arange(1, 3, 0.01)
y = qinjiushao(factors,x)

plt.plot(x,y)
plt.show()

# %%
x = np.arange(1, 3, 0.001)

plt.plot(x,(x-2)**9)
plt.show()
